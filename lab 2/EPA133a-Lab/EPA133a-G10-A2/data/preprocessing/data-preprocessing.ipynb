# %%
import pandas as pd
import numpy as np

# read files
roads = pd.read_csv("_roads3.csv")
bridges = pd.read_excel("BMMS_overview.xlsx")

# filter + select
roads = roads.loc[roads["road"] == "N1", ["road", "lrp", "lat", "lon", "chainage"]]
bridges = bridges.loc[bridges["road"] == "N1", ["LRPName", "length", "condition", "constructionYear"]]

# merge
roads = roads.merge(bridges, how="left", left_on="lrp", right_on="LRPName")

# model type
roads["model_type"] = np.select(
    [
        roads["lrp"] == "LRPS",
        roads["lrp"] == "LRPE",
        roads["length"].notna()
    ],
    ["source", "sink", "bridge"],
    default="link"
)

# compute length
roads["length"] = roads["length"].fillna(
    (roads["chainage"].shift(-1) - roads["chainage"]) * 1000
)

# rename
roads = roads.rename(columns={"lrp": "name"})

# --- SIMPLE PRIORITY LOGIC ---

quality_rank = {"A": 4, "B": 3, "C": 2, "D": 1}

roads["constructionYear"] = pd.to_numeric(roads["constructionYear"], errors="coerce")
roads["quality_score"] = roads["condition"].map(quality_rank).fillna(0)

roads = (
    roads.assign(all_have_year=roads.groupby("name")["constructionYear"].transform(lambda x: x.notna().all()))
         .drop_duplicates("name", keep="last")
         .drop(columns="all_have_year")
)

# cleanup
roads = (roads.drop(columns=["LRPName", "chainage"]).reset_index(drop=True))

roads.insert(0, "id", roads.index + 1)

roads.to_csv("processed_data.csv", index=False)
display(roads)
# Out:
#         id road     name        lat        lon  length condition  \
# 0        1   N1     LRPS  23.706028  90.443333   814.0       NaN
# 1        2   N1    LRPSa  23.702917  90.450417     8.0       NaN
# 2        3   N1    LRPSb  23.702778  90.450472   178.0       NaN
# 3        4   N1   LRP001  23.702139  90.451972  1000.0       NaN
# 4        5   N1   LRP002  23.697889  90.460583   130.0       NaN
# ...    ...  ...      ...        ...        ...     ...       ...
# 1334  1335   N1  LRP466a  20.868860  92.298222   428.0       NaN
# 1335  1336   N1  LRP466b  20.865028  92.298250    42.0       NaN
# 1336  1337   N1  LRP466c  20.864667  92.298194   178.0       NaN
# 1337  1338   N1   LRP467  20.862972  92.298083   130.0       NaN
# 1338  1339   N1     LRPE  20.862917  92.298083     NaN       NaN
#
#       constructionYear model_type  quality_score
# 0                  NaN     source            0.0
# 1                  NaN       link            0.0
# ...
